# %% [markdown]
# ## Run the daq and process data on Stoomboot!

# %% [markdown]
# ### Step 1

# %%
import pymongo
import os

# %%
c = pymongo.MongoClient(f'mongodb://{os.environ["MONGO_USER"]}:{os.environ["MONGO_PASSWORD"]}@127.0.0.1:27017/admin')

# %%
c.list_database_names()
# Out:
# ['admin',
#  'bootstrax',
#  'config',
#  'daq',
#  'local',
#  'log',
#  'run',
#  'runs',
#  'testdb',
#  'usage',
#  'xenonnt']

# %%
# We take the new run collection and we sort the document with the start time 
c['run']['runs_new'].find_one(sort=[('number', -1)])['start']
# Out:
# datetime.datetime(2021, 6, 15, 9, 59, 28, 575000)

# %%
# !ls /data/xenon/xams/run11
# Out:
# 000082	000089	000096	000103	000110	000117	000124	000131	000138
# 000083	000090	000097	000104	000111	000118	000125	000132	000139
# 000084	000091	000098	000105	000112	000119	000126	000133	processed
# 000085	000092	000099	000106	000113	000120	000127	000134
# 000086	000093	000100	000107	000114	000121	000128	000135
# 000087	000094	000101	000108	000115	000122	000129	000136
# 000088	000095	000102	000109	000116	000123	000130	000137

# %% [markdown]
# ### Step 2
#
# Update the options document you need by using the script ``daq/redax/helpers/set_run_mode.py``
#
# If you change the mode you should also add it in the desired mode otherwise it won't work.

# %%
# !python ~/daq/redax/helpers/set_run_mode.py

# %%
# !cat ~/daq/redax/helpers/set_run_mode.py | grep "name" | head -1
# Out:
#         "name": "Run0_V1730_check", #the first digitizer is the lead clock

# %% [markdown]
# ### Step 3
#
# Start a run by changing the `active` field from `false` to `true` in the script ``daq/redax/helpers/detector_state.py``

# %%
#!python ~/daq/redax/helpers/detector_state.py --active false --mode Run0_V1724_V1730
# !python ~/daq/redax/helpers/detector_state.py --active false --mode Run0_V1724_check
#!python ~/daq/redax/helpers/detector_state.py --active false --mode Run0_V1730_check

# %%
#!python ~/daq/redax/helpers/detector_state.py --active true --mode Run0_V1724_V1730
# !python ~/daq/redax/helpers/detector_state.py --active true --mode Run0_V1724_check
#!python ~/daq/redax/helpers/detector_state.py --active true --mode Run0_V1730_check

# %% [markdown]
# ### Step 4
#
# Let's now run bootstrax in the folder ``amstrax/autoprocessing/bootstrax.py``

# %%
from pprint import pprint

# %%
pprint(c['run']['runs_new'].find_one(sort=[('number', -1)]));
# Out:
# {'_id': ObjectId('60c87a029478fd816675f072'),
#  'comments': [{'comment': ' ',
#                'date': datetime.datetime(2021, 6, 15, 9, 59, 28, 573000),
#                'user': 'sdipede'}],
#  'daq_config': {'_id': ObjectId('60ae1ae01b2e52e67abe3616'),
#                 'baseline_adjustment_threshold': 10,
#                 'baseline_bins_around_max': 4,
#                 'baseline_convergence_threshold': 3,
#                 'baseline_dac_mode': 'fixed',
#                 'baseline_fixed_value': 4000,
#                 'baseline_fraction_around_max': 0.5,
#                 'baseline_max_iterations': 2,
#                 'baseline_max_steps': 30,
#                 'baseline_min_adjustment': 10,
#                 'baseline_ms_between_triggers': 10,
#                 'baseline_rebin_log2': 2,
#                 'baseline_triggers_per_step': 3,
#                 'baseline_value': 16000,
#                 'blt_safety_factor': 1.5,
#                 'boards': [{'board': 770,
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 139 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 139 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 139 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 139 --target peak_basics
# Out:
# considering
# 2021-06-15 13:39:59,908 | INFO | Starting processing of run 139
#   1435 MainThread main Starting processing of run 139
# 2021-06-15 13:39:59,913 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1441 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-15 13:39:59,914 | INFO | Starting strax to make 000139 with input dir /data/xenon/xams/run11/000139
#   1441 MainThread main Starting strax to make 000139 with input dir /data/xenon/xams/run11/000139
# 2021-06-15 13:39:59,914 | INFO | Still processing run 000139
#   1441 MainThread main Still processing run 000139
# busy
# 2021-06-15 13:40:09,923 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#  11450 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
#!python /home/xams/amstrax/autoprocessing/bootstrax.py --process 138 --target raw_records
#!python /home/xams/amstrax/autoprocessing/bootstrax.py --process 138 --target records
#!python /home/xams/amstrax/autoprocessing/bootstrax.py --process 138 --target peaks
#!python /home/xams/amstrax/autoprocessing/bootstrax.py --process 138 --target peak_basics

# %%
#!python /home/xams/amstrax/autoprocessing/bootstrax.py --process 137 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 137 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 137 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 137 --target peak_basics
# Out:
# considering
# 2021-06-14 17:54:22,712 | INFO | Starting processing of run 137
#   1438 MainThread main Starting processing of run 137
# 2021-06-14 17:54:23,727 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   2453 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-14 17:54:23,727 | INFO | Starting strax to make 000137 with input dir /data/xenon/xams/run11/000137
#   2453 MainThread main Starting strax to make 000137 with input dir /data/xenon/xams/run11/000137
# 2021-06-14 17:54:23,727 | INFO | Still processing run 000137
#   2453 MainThread main Still processing run 000137
# busy
# 2021-06-14 17:54:33,735 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#  12461 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
#!python /home/xams/amstrax/autoprocessing/bootstrax.py --process 136 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 136 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 136 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 136 --target peak_basics
# Out:
# considering
# 2021-06-14 17:55:41,693 | INFO | Starting processing of run 136
#   1399 MainThread main Starting processing of run 136
# 2021-06-14 17:55:42,437 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   2142 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-14 17:55:42,437 | INFO | Starting strax to make 000136 with input dir /data/xenon/xams/run11/000136
# 2021-06-14 17:55:42,438 | INFO | Still processing run 000136
#   2143 MainThread main Still processing run 000136
#   2143 MainThread main Starting strax to make 000136 with input dir /data/xenon/xams/run11/000136
# busy
# 2021-06-14 17:55:52,451 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#  12156 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 125 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 125 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 125 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 125 --target peak_basics
# Out:
# considering
# 2021-06-04 15:16:25,760 | INFO | Starting processing of run 125
#   1674 MainThread main Starting processing of run 125
# 2021-06-04 15:16:25,768 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-04 15:16:25,768 | INFO | Starting strax to make 000125 with input dir /data/xenon/xams/run11/000125
#   1682 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1682 MainThread main Starting strax to make 000125 with input dir /data/xenon/xams/run11/000125
# 2021-06-04 15:16:25,768 | INFO | Still processing run 000125
#   1682 MainThread main Still processing run 000125
# busy
# Source finished!
# 2021-06-04 15:16:35,780 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 124 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 124 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 124 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 124 --target peak_basics
# Out:
# considering
# 2021-06-04 15:08:25,915 | INFO | Starting processing of run 124
#   1474 MainThread main Starting processing of run 124
# 2021-06-04 15:08:25,922 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1481 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-04 15:08:25,923 | INFO | Still processing run 000124
#   1482 MainThread main Still processing run 000124
# busy
# 2021-06-04 15:08:25,924 | INFO | Starting strax to make 000124 with input dir /data/xenon/xams/run11/000124
#   1483 MainThread main Starting strax to make 000124 with input dir /data/xenon/xams/run11/000124
# Source finished!
# 2021-06-04 15:08:35,935 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 123 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 123 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 123 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 123 --target peak_basics
# Out:
# considering
# 2021-06-04 14:57:06,366 | INFO | Starting processing of run 123
#   1473 MainThread main Starting processing of run 123
# 2021-06-04 14:57:06,375 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1483 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-04 14:57:06,376 | INFO | Starting strax to make 000123 with input dir /data/xenon/xams/run11/000123
# 2021-06-04 14:57:06,376 | INFO | Still processing run 000123
#   1483 MainThread main Starting strax to make 000123 with input dir /data/xenon/xams/run11/000123
#   1483 MainThread main Still processing run 000123
# busy
# Source finished!
# 2021-06-04 14:57:16,383 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 122 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 122 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 122 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 122 --target peak_basics
# Out:
# considering
# 2021-06-04 14:47:03,812 | INFO | Starting processing of run 122
#   1589 MainThread main Starting processing of run 122
# 2021-06-04 14:47:03,818 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1594 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-04 14:47:03,818 | INFO | Starting strax to make 000122 with input dir /data/xenon/xams/run11/000122
# 2021-06-04 14:47:03,818 | INFO | Still processing run 000122
#   1595 MainThread main Still processing run 000122
# busy
#   1595 MainThread main Starting strax to make 000122 with input dir /data/xenon/xams/run11/000122
# Source finished!
# 2021-06-04 14:47:13,831 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 121 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 121 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 121 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 121 --target peak_basics
# Out:
# considering
# 2021-06-04 14:41:45,162 | INFO | Starting processing of run 121
#   1508 MainThread main Starting processing of run 121
# 2021-06-04 14:41:45,168 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1515 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-04 14:41:45,168 | INFO | Starting strax to make 000121 with input dir /data/xenon/xams/run11/000121
#   1515 MainThread main Starting strax to make 000121 with input dir /data/xenon/xams/run11/000121
# 2021-06-04 14:41:45,169 | INFO | Still processing run 000121
#   1515 MainThread main Still processing run 000121
# busy
# Source finished!
# 2021-06-04 14:41:55,179 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 120 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 120 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 120 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 120 --target peak_basics
# Out:
# considering
# 2021-06-04 14:26:49,289 | INFO | Starting processing of run 120
#   1488 MainThread main Starting processing of run 120
# 2021-06-04 14:26:49,298 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1497 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-04 14:26:49,298 | INFO | Starting strax to make 000120 with input dir /data/xenon/xams/run11/000120
# 2021-06-04 14:26:49,298 | INFO | Still processing run 000120
#   1497 MainThread main Still processing run 000120
# busy
#   1497 MainThread main Starting strax to make 000120 with input dir /data/xenon/xams/run11/000120
# Source finished!
# 2021-06-04 14:26:59,307 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 119 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 119 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 119 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 119 --target peak_basics
# Out:
# considering
# 2021-06-03 19:38:22,076 | INFO | Starting processing of run 119
#   1739 MainThread main Starting processing of run 119
# 2021-06-03 19:38:22,083 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-03 19:38:22,083 | INFO | Starting strax to make 000119 with input dir /data/xenon/xams/run11/000119
#   1746 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1746 MainThread main Starting strax to make 000119 with input dir /data/xenon/xams/run11/000119
# 2021-06-03 19:38:22,084 | INFO | Still processing run 000119
#   1746 MainThread main Still processing run 000119
# busy
# Source finished!
# 2021-06-03 19:38:32,095 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 118 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 118 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 118 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 118 --target peak_basics
# Out:
# considering
# 2021-06-03 19:37:31,690 | INFO | Starting processing of run 118
#   1620 MainThread main Starting processing of run 118
# 2021-06-03 19:37:31,697 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1626 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-03 19:37:31,697 | INFO | Starting strax to make 000118 with input dir /data/xenon/xams/run11/000118
#   1627 MainThread main Starting strax to make 000118 with input dir /data/xenon/xams/run11/000118
# 2021-06-03 19:37:31,697 | INFO | Still processing run 000118
#   1627 MainThread main Still processing run 000118
# busy
# Source finished!
# 2021-06-03 19:37:41,707 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 117 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 117 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 117 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 117 --target peak_basics
# Out:
# considering
# 2021-06-03 19:36:41,615 | INFO | Starting processing of run 117
#   1815 MainThread main Starting processing of run 117
# 2021-06-03 19:36:41,622 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1822 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-03 19:36:41,623 | INFO | Still processing run 000117
#   1822 MainThread main Still processing run 000117
# busy
# 2021-06-03 19:36:41,623 | INFO | Starting strax to make 000117 with input dir /data/xenon/xams/run11/000117
#   1822 MainThread main Starting strax to make 000117 with input dir /data/xenon/xams/run11/000117
# Source finished!
# 2021-06-03 19:36:51,635 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 116 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 116 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 116 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 116 --target peak_basics
# Out:
# considering
# 2021-06-03 19:35:51,263 | INFO | Starting processing of run 116
#   1640 MainThread main Starting processing of run 116
# 2021-06-03 19:35:51,270 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-03 19:35:51,270 | INFO | Starting strax to make 000116 with input dir /data/xenon/xams/run11/000116
#   1647 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1647 MainThread main Starting strax to make 000116 with input dir /data/xenon/xams/run11/000116
# 2021-06-03 19:35:51,271 | INFO | Still processing run 000116
#   1647 MainThread main Still processing run 000116
# busy
# Source finished!
# 2021-06-03 19:36:01,280 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 115 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 115 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 115 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 115 --target peak_basics
# Out:
# considering
# 2021-06-03 19:34:57,693 | INFO | Starting processing of run 115
#   1539 MainThread main Starting processing of run 115
# 2021-06-03 19:34:57,700 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1546 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-03 19:34:57,700 | INFO | Starting strax to make 000115 with input dir /data/xenon/xams/run11/000115
# 2021-06-03 19:34:57,700 | INFO | Still processing run 000115
#   1547 MainThread main Still processing run 000115
#   1547 MainThread main Starting strax to make 000115 with input dir /data/xenon/xams/run11/000115
# busy
# Source finished!
# 2021-06-03 19:35:07,711 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 114 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 114 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 114 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 114 --target peak_basics
# Out:
# considering
# 2021-06-03 19:34:07,925 | INFO | Starting processing of run 114
#   1484 MainThread main Starting processing of run 114
# 2021-06-03 19:34:07,932 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1491 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-03 19:34:07,932 | INFO | Starting strax to make 000114 with input dir /data/xenon/xams/run11/000114
# 2021-06-03 19:34:07,932 | INFO | Still processing run 000114
#   1491 MainThread main Starting strax to make 000114 with input dir /data/xenon/xams/run11/000114
#   1491 MainThread main Still processing run 000114
# busy
# Source finished!
# 2021-06-03 19:34:17,943 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 113 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 113 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 113 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 113 --target peak_basics
# Out:
# considering
# 2021-06-03 19:33:18,017 | INFO | Starting processing of run 113
#   1522 MainThread main Starting processing of run 113
# 2021-06-03 19:33:18,399 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-03 19:33:18,399 | INFO | Starting strax to make 000113 with input dir /data/xenon/xams/run11/000113
#   1904 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1905 MainThread main Starting strax to make 000113 with input dir /data/xenon/xams/run11/000113
# 2021-06-03 19:33:18,400 | INFO | Still processing run 000113
#   1905 MainThread main Still processing run 000113
# busy
# Source finished!
# 2021-06-03 19:33:28,413 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 111 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 111 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 111 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 111 --target peak_basics
# Out:
# considering
# 2021-06-01 13:15:49,364 | INFO | Starting processing of run 111
#   1489 MainThread main Starting processing of run 111
# 2021-06-01 13:15:49,371 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-01 13:15:49,372 | INFO | Starting strax to make 000111 with input dir /data/xenon/xams/run11/000111
#   1497 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1497 MainThread main Starting strax to make 000111 with input dir /data/xenon/xams/run11/000111
# 2021-06-01 13:15:49,372 | INFO | Still processing run 000111
#   1498 MainThread main Still processing run 000111
# busy
# 2021-06-01 13:15:59,383 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#  11509 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 113 --target raw_records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 113 --target records
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 113 --target peaks
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 113 --target peak_basics
# Out:
# considering
# 2021-06-03 16:54:24,734 | INFO | Starting processing of run 113
#   1469 MainThread main Starting processing of run 113
# 2021-06-03 16:54:24,744 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1480 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-06-03 16:54:24,744 | INFO | Starting strax to make 000113 with input dir /data/xenon/xams/run11/000113
# 2021-06-03 16:54:24,745 | INFO | Still processing run 000113
#   1480 MainThread main Still processing run 000113
# busy
#   1480 MainThread main Starting strax to make 000113 with input dir /data/xenon/xams/run11/000113
# Source finished!
# 2021-06-03 16:54:34,757 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 98 --target raw_records
# Out:
# considering
# 2021-05-26 12:58:58,346 | INFO | Starting processing of run 98
#   1479 MainThread main Starting processing of run 98
# 2021-05-26 12:58:58,356 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-05-26 12:58:58,356 | INFO | Starting strax to make 000098 with input dir /data/xenon/xams/run11/000098
#   1489 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1489 MainThread main Starting strax to make 000098 with input dir /data/xenon/xams/run11/000098
# 2021-05-26 12:58:58,356 | INFO | Still processing run 000098
#   1490 MainThread main Still processing run 000098
# busy
# Read chunk 000000 from DAQ
# 	[000098.raw_records_sipm: 0sec 0 ns - 5sec 499999000 ns, 22000 items, 1.0 MB/s]
# 	[000098.raw_records: 0sec 0 ns - 5sec 499999000 ns, 0 items, 0.0 MB/s]
# Read chunk 000001 from DAQ
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 97 --target peaks_top
# Out:
# In the main
# process
# considering
# 2021-05-25 16:22:50,721 | INFO | Starting processing of run 97
#   1476 MainThread main Starting processing of run 97
# shortcut failing
# 2021-05-25 16:22:50,837 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1592 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-05-25 16:22:50,838 | INFO | Starting strax to make 000097 with input dir /data/xenon/xams/run11/000097
#   1593 MainThread main Starting strax to make 000097 with input dir /data/xenon/xams/run11/000097
# 2021-05-25 16:22:50,838 | INFO | Still processing run 000097
#   1593 MainThread main Still processing run 000097
# busy
# Read chunk 000000 from DAQ
# 	[000097.raw_records_sipm: 0sec 0 ns - 5sec 499999000 ns, 11000 items, 0.5 MB/s]
# 	[000097.raw_records: 0sec 0 ns - 5sec 499999000 ns, 38500 items, 1.7 MB/s]
# Read chunk 000001 from DAQ
# ...

# %%
# !python /home/xams/amstrax/autoprocessing/bootstrax.py --process 97 --target peaks_bottom
# Out:
# In the main
# process
# considering
# 2021-05-25 16:23:03,284 | INFO | Starting processing of run 97
#   1581 MainThread main Starting processing of run 97
# shortcut failing
# 2021-05-25 16:23:03,489 | DEBUG | Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
#   1786 MainThread main Not updating bootstrax doc: none selected. You are probably running a rogue bootstrax operation...
# 2021-05-25 16:23:03,489 | INFO | Starting strax to make 000097 with input dir /data/xenon/xams/run11/000097
#   1786 MainThread main Starting strax to make 000097 with input dir /data/xenon/xams/run11/000097
# 2021-05-25 16:23:03,490 | INFO | Still processing run 000097
#   1787 MainThread main Still processing run 000097
# busy
# Read chunk 000000 from DAQ
# 	[000097.raw_records_sipm: 0sec 0 ns - 5sec 499999000 ns, 11000 items, 0.5 MB/s]
# 	[000097.raw_records: 0sec 0 ns - 5sec 499999000 ns, 38500 items, 1.7 MB/s]
# Read chunk 000001 from DAQ
# ...

# %% [markdown]
# The logs are saved into the folder ```/home/xams/logs```

# %% [markdown]
# ### Step 5
# Let's have a look at the results we got so far.

# %%
import pandas as pd
from collections import defaultdict

# %%
runs = list(c['run']['runs_new'].find({'number':{"$gt":112}}))
runs
# Out:
# [{'_id': ObjectId('60b8ebbc8eac58336f4d188f'),
#   'number': 113,
#   'detectors': ['xams'],
#   'user': 'sdipede',
#   'mode': 'Run0_V1724_check',
#   'daq_config': {'_id': ObjectId('60ae1ae01b2e52e67abe3616'),
#    'name': 'Run0_V1724_check',
#    'user': 'dipede',
#    'description': 'This is a check to process data with the options to set for XAMSL',
#    'detector': 'xams',
#    'run_start': 0,
#    'compressor': 'lz4',
#    'processing_threads': {'xams-daq_reader_0': 1},
#    'firmware_version': 0,
#    'baseline_dac_mode': 'fixed',
#    'baseline_value': 16000,
#    'baseline_fixed_value': 4000,
#    'detectors': {'xams-daq_reader_0': 'xams'},
#    'baseline_max_iterations': 2,
#    'baseline_max_steps': 30,
#    'baseline_adjustment_threshold': 10,
#    'baseline_convergence_threshold': 3,
#    'baseline_min_adjustment': 10,
#    'baseline_rebin_log2': 2,
#    'baseline_bins_around_max': 4,
#    'baseline_fraction_around_max': 0.5,
#    'baseline_triggers_per_step': 3,
# ...

# %%
web_page = defaultdict(list)
for k in ['number', 'mode']:
    web_page[k] = [v[k] for v in runs]
for p in ['started_processing']:
    web_page[p] = [v['bootstrax'][p] for v in runs]
for bk in ['state', 'n_failures','reason']:
    web_page[f'bootstrax_{bk}'] = [v['bootstrax'].get(bk, None) for v in runs]
for r in ['host']:
    web_page[r] = [v['bootstrax'][r] for v in runs]
#for t in ['time']:
#    web_page[t] = [v['bootstrax'][t] for v in runs]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-19828cfbf922> in <module>
#       3     web_page[k] = [v[k] for v in runs]
#       4 for p in ['started_processing']:
# ----> 5     web_page[p] = [v['bootstrax'][p] for v in runs]
#       6 for bk in ['state', 'n_failures','reason']:
#       7     web_page[f'bootstrax_{bk}'] = [v['bootstrax'].get(bk, None) for v in runs]
#
# <ipython-input-9-19828cfbf922> in <listcomp>(.0)
#       3     web_page[k] = [v[k] for v in runs]
#       4 for p in ['started_processing']:
# ----> 5     web_page[p] = [v['bootstrax'][p] for v in runs]
#       6 for bk in ['state', 'n_failures','reason']:
#       7     web_page[f'bootstrax_{bk}'] = [v['bootstrax'].get(bk, None) for v in runs]
#
# KeyError: 'bootstrax'

# %%
pd.DataFrame(web_page)
# Out:
#     number              mode      started_processing bootstrax_state  \
# 0      113  Run0_V1724_check 2021-06-03 17:33:55.665            done
# 1      114  Run0_V1724_check 2021-06-03 17:34:45.433            done
# 2      115  Run0_V1724_check 2021-06-03 17:35:35.577            done
# 3      116  Run0_V1724_check 2021-06-03 17:36:28.972            done
# 4      117  Run0_V1724_check 2021-06-03 17:37:19.249            done
# 5      118  Run0_V1724_check 2021-06-03 17:38:09.588            done
# 6      119  Run0_V1724_check 2021-06-03 17:38:59.414            done
# 7      120  Run0_V1724_check 2021-06-04 12:27:26.829            done
# 8      121  Run0_V1724_check 2021-06-04 12:42:22.660            done
# 9      122  Run0_V1724_check 2021-06-04 12:47:41.274            done
# 10     123  Run0_V1724_check 2021-06-04 12:57:43.702            done
# 11     124  Run0_V1724_check 2021-06-04 13:09:03.284            done
# 12     125  Run0_V1724_check 2021-06-04 13:17:03.332            done
# ...

# %%
provides=('raw_records',)
record_length=110

# %%
bla.keys()
# Out:
# dict_keys(['raw_records'])

# %%
bla['raw_records']
# Out:
# [(('Start time since unix epoch [ns]', 'time'), numpy.int64),
#  (('Length of the interval in samples', 'length'), numpy.int32),
#  (('Width of one sample [ns]', 'dt'), numpy.int16),
#  (('Channel/PMT number', 'channel'), numpy.int16),
#  (('Length of pulse to which the record belongs (without zero-padding)',
#    'pulse_length'),
#   numpy.int32),
#  (('Fragment number in the pulse', 'record_i'), numpy.int16),
#  (('Baseline determined by the digitizer (if this is supported)', 'baseline'),
#   numpy.int16),
#  (('Waveform data in raw ADC counts', 'data'), numpy.int16, 110)]
